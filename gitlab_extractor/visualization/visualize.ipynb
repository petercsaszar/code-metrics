# %% [markdown]
# # Visualize results of code metrics analyzer

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import os
import json

# %% [markdown]
# ## Prepare data

# %% [markdown]
# Extract values from file

# %%
bumpy_data = {}
fpc_data = {}
lcom5_data = {}
lcom4_data = {}

i = 1
for filename in os.listdir("../"):
    if filename.endswith(".json") and filename != "public_analysis_results.json":  # Adjust for file format
        filepath = os.path.join("../", filename)
        with open(filepath, "r") as file:
            json_object = json.load(file)
            projects = [{"project_id": key, **value} for key, value in json_object.items()]
            for project in projects:
                # bumpy road
                score = project["bumpy_score"]
                project_id = project["project_id"]
                if project_id not in bumpy_data:
                    bumpy_data[project_id] = {}
                milestone = "Milestone " + str(i)
                bumpy_data[project_id][milestone] = score

                # fpc
                score = project["fpc_score"]
                project_id = project["project_id"]
                if project_id not in fpc_data:
                    fpc_data[project_id] = {}
                milestone = "Milestone " + str(i)
                fpc_data[project_id][milestone] = score

                # lcom5
                score = project["lcom5_score"]
                project_id = project["project_id"]
                if project_id not in lcom5_data:
                    lcom5_data[project_id] = {}
                milestone = "Milestone " + str(i)
                lcom5_data[project_id][milestone] = score

                # lcom4
                score = project["lcom4_score"]
                project_id = project["project_id"]
                if project_id not in lcom4_data:
                    lcom4_data[project_id] = {}
                milestone = "Milestone " + str(i)
                lcom4_data[project_id][milestone] = score
        i += 1

print(bumpy_data)
print(fpc_data)
print(lcom5_data)
print(lcom4_data)
# Out:
# {996: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 993: {'Milestone 1': 7, 'Milestone 2': 15, 'Milestone 3': 15}, 992: {'Milestone 1': 3, 'Milestone 2': 5, 'Milestone 3': 6}, 989: {'Milestone 1': 4, 'Milestone 2': 5, 'Milestone 3': 6}, 899: {'Milestone 1': 2, 'Milestone 2': 2, 'Milestone 3': 10}, 898: {'Milestone 1': 0, 'Milestone 2': 0}, 897: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 896: {'Milestone 1': 1, 'Milestone 2': 1, 'Milestone 3': 3}, 986: {'Milestone 1': 7, 'Milestone 2': 10, 'Milestone 3': 10}, 842: {'Milestone 1': 1, 'Milestone 2': 5, 'Milestone 3': 5}, 1004: {'Milestone 1': 1, 'Milestone 2': 6, 'Milestone 3': 6}, 922: {'Milestone 1': 1, 'Milestone 2': 4, 'Milestone 3': 3}, 854: {'Milestone 1': 1, 'Milestone 2': 2, 'Milestone 3': 2}, 860: {'Milestone 1': 3, 'Milestone 2': 11, 'Milestone 3': 11}, 858: {'Milestone 1': 1, 'Milestone 2': 9, 'Milestone 3': 12}, 857: {'Milestone 1': 4, 'Milestone 2': 5, 'Milestone 3': 7}, 950: {'Milestone 1': 3, 'Milestone 2': 5, 'Milestone 3': 8}, 948: {'Milestone 1': 6, 'Milestone 2': 4, 'Milestone 3': 4}, 947: {'Milestone 1': 0, 'Milestone 2': 6, 'Milestone 3': 5}, 944: {'Milestone 1': 6, 'Milestone 2': 16, 'Milestone 3': 14}, 971: {'Milestone 1': 4, 'Milestone 2': 4}, 938: {'Milestone 1': 2, 'Milestone 3': 5}, 936: {'Milestone 1': 3, 'Milestone 2': 7, 'Milestone 3': 8}, 935: {'Milestone 1': 2, 'Milestone 2': 2, 'Milestone 3': 6}, 934: {'Milestone 1': 3, 'Milestone 3': 18}, 988: {'Milestone 1': 0, 'Milestone 3': 9}, 964: {'Milestone 1': 1, 'Milestone 2': 6, 'Milestone 3': 6}, 963: {'Milestone 1': 5, 'Milestone 2': 11, 'Milestone 3': 12}, 943: {'Milestone 1': 6, 'Milestone 2': 6, 'Milestone 3': 6}, 942: {'Milestone 1': 1, 'Milestone 2': 2, 'Milestone 3': 2}, 941: {'Milestone 1': 1, 'Milestone 2': 3, 'Milestone 3': 4}, 940: {'Milestone 1': 4, 'Milestone 2': 35, 'Milestone 3': 32}, 983: {'Milestone 1': 0, 'Milestone 2': 6, 'Milestone 3': 5}, 982: {'Milestone 1': 2, 'Milestone 2': 8, 'Milestone 3': 8}, 981: {'Milestone 1': 3, 'Milestone 2': 22, 'Milestone 3': 22}, 979: {'Milestone 1': 7, 'Milestone 2': 8, 'Milestone 3': 8}, 937: {'Milestone 2': 5, 'Milestone 3': 6}, 906: {'Milestone 2': 5, 'Milestone 3': 5}, 962: {'Milestone 2': 9, 'Milestone 3': 9}, 961: {'Milestone 2': 14, 'Milestone 3': 18}, 980: {'Milestone 2': 11, 'Milestone 3': 13}}
# {996: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 993: {'Milestone 1': 1, 'Milestone 2': 7, 'Milestone 3': 10}, 992: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 1}, 989: {'Milestone 1': 17, 'Milestone 2': 17, 'Milestone 3': 18}, 899: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 898: {'Milestone 1': 2, 'Milestone 2': 2}, 897: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 896: {'Milestone 1': 4, 'Milestone 2': 4, 'Milestone 3': 4}, 986: {'Milestone 1': 4, 'Milestone 2': 5, 'Milestone 3': 5}, 842: {'Milestone 1': 3, 'Milestone 2': 4, 'Milestone 3': 4}, 1004: {'Milestone 1': 1, 'Milestone 2': 2, 'Milestone 3': 2}, 922: {'Milestone 1': 0, 'Milestone 2': 3, 'Milestone 3': 3}, 854: {'Milestone 1': 0, 'Milestone 2': 3, 'Milestone 3': 3}, 860: {'Milestone 1': 6, 'Milestone 2': 8, 'Milestone 3': 9}, 858: {'Milestone 1': 0, 'Milestone 2': 2, 'Milestone 3': 2}, 857: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 1}, 950: {'Milestone 1': 2, 'Milestone 2': 6, 'Milestone 3': 7}, 948: {'Milestone 1': 3, 'Milestone 2': 6, 'Milestone 3': 6}, 947: {'Milestone 1': 2, 'Milestone 2': 6, 'Milestone 3': 8}, 944: {'Milestone 1': 2, 'Milestone 2': 0, 'Milestone 3': 3}, 971: {'Milestone 1': 0, 'Milestone 2': 0}, 938: {'Milestone 1': 0, 'Milestone 3': 2}, 936: {'Milestone 1': 2, 'Milestone 2': 8, 'Milestone 3': 7}, 935: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 1}, 934: {'Milestone 1': 0, 'Milestone 3': 19}, 988: {'Milestone 1': 0, 'Milestone 3': 11}, 964: {'Milestone 1': 4, 'Milestone 2': 5, 'Milestone 3': 5}, 963: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 1}, 943: {'Milestone 1': 28, 'Milestone 2': 28, 'Milestone 3': 28}, 942: {'Milestone 1': 2, 'Milestone 2': 1, 'Milestone 3': 2}, 941: {'Milestone 1': 0, 'Milestone 2': 1, 'Milestone 3': 1}, 940: {'Milestone 1': 7, 'Milestone 2': 15, 'Milestone 3': 13}, 983: {'Milestone 1': 0, 'Milestone 2': 2, 'Milestone 3': 2}, 982: {'Milestone 1': 1, 'Milestone 2': 5, 'Milestone 3': 7}, 981: {'Milestone 1': 4, 'Milestone 2': 5, 'Milestone 3': 5}, 979: {'Milestone 1': 1, 'Milestone 2': 1, 'Milestone 3': 3}, 937: {'Milestone 2': 0, 'Milestone 3': 4}, 906: {'Milestone 2': 1, 'Milestone 3': 5}, 962: {'Milestone 2': 0, 'Milestone 3': 0}, 961: {'Milestone 2': 2, 'Milestone 3': 2}, 980: {'Milestone 2': 12, 'Milestone 3': 17}}
# {996: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 993: {'Milestone 1': 21, 'Milestone 2': 34, 'Milestone 3': 34}, 992: {'Milestone 1': 12, 'Milestone 2': 24, 'Milestone 3': 25}, 989: {'Milestone 1': 23, 'Milestone 2': 27, 'Milestone 3': 28}, 899: {'Milestone 1': 13, 'Milestone 2': 13, 'Milestone 3': 15}, 898: {'Milestone 1': 7, 'Milestone 2': 7}, 897: {'Milestone 1': 6, 'Milestone 2': 6, 'Milestone 3': 6}, 896: {'Milestone 1': 9, 'Milestone 2': 9, 'Milestone 3': 9}, 986: {'Milestone 1': 11, 'Milestone 2': 18, 'Milestone 3': 18}, 842: {'Milestone 1': 12, 'Milestone 2': 15, 'Milestone 3': 16}, 1004: {'Milestone 1': 8, 'Milestone 2': 13, 'Milestone 3': 14}, 922: {'Milestone 1': 18, 'Milestone 2': 33, 'Milestone 3': 34}, 854: {'Milestone 1': 18, 'Milestone 2': 69, 'Milestone 3': 69}, 860: {'Milestone 1': 16, 'Milestone 2': 26, 'Milestone 3': 28}, 858: {'Milestone 1': 16, 'Milestone 2': 25, 'Milestone 3': 29}, 857: {'Milestone 1': 15, 'Milestone 2': 34, 'Milestone 3': 36}, 950: {'Milestone 1': 9, 'Milestone 2': 14, 'Milestone 3': 14}, 948: {'Milestone 1': 12, 'Milestone 2': 14, 'Milestone 3': 14}, 947: {'Milestone 1': 12, 'Milestone 2': 22, 'Milestone 3': 24}, 944: {'Milestone 1': 9, 'Milestone 2': 15, 'Milestone 3': 16}, 971: {'Milestone 1': 13, 'Milestone 2': 13}, 938: {'Milestone 1': 9, 'Milestone 3': 14}, 936: {'Milestone 1': 12, 'Milestone 2': 15, 'Milestone 3': 16}, 935: {'Milestone 1': 11, 'Milestone 2': 12, 'Milestone 3': 15}, 934: {'Milestone 1': 4, 'Milestone 3': 18}, 988: {'Milestone 1': 8, 'Milestone 3': 16}, 964: {'Milestone 1': 9, 'Milestone 2': 11, 'Milestone 3': 11}, 963: {'Milestone 1': 8, 'Milestone 2': 12, 'Milestone 3': 13}, 943: {'Milestone 1': 19, 'Milestone 2': 19, 'Milestone 3': 19}, 942: {'Milestone 1': 7, 'Milestone 2': 9, 'Milestone 3': 10}, 941: {'Milestone 1': 15, 'Milestone 2': 29, 'Milestone 3': 31}, 940: {'Milestone 1': 9, 'Milestone 2': 20, 'Milestone 3': 24}, 983: {'Milestone 1': 0, 'Milestone 2': 6, 'Milestone 3': 7}, 982: {'Milestone 1': 7, 'Milestone 2': 20, 'Milestone 3': 20}, 981: {'Milestone 1': 13, 'Milestone 2': 19, 'Milestone 3': 20}, 979: {'Milestone 1': 7, 'Milestone 2': 13, 'Milestone 3': 13}, 937: {'Milestone 2': 8, 'Milestone 3': 11}, 906: {'Milestone 2': 25, 'Milestone 3': 25}, 962: {'Milestone 2': 14, 'Milestone 3': 14}, 961: {'Milestone 2': 18, 'Milestone 3': 19}, 980: {'Milestone 2': 13, 'Milestone 3': 15}}
# {996: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 993: {'Milestone 1': 3, 'Milestone 2': 5, 'Milestone 3': 6}, 992: {'Milestone 1': 3, 'Milestone 2': 6, 'Milestone 3': 6}, 989: {'Milestone 1': 6, 'Milestone 2': 6, 'Milestone 3': 7}, 899: {'Milestone 1': 6, 'Milestone 2': 6, 'Milestone 3': 9}, 898: {'Milestone 1': 3, 'Milestone 2': 3}, 897: {'Milestone 1': 0, 'Milestone 2': 0, 'Milestone 3': 0}, 896: {'Milestone 1': 3, 'Milestone 2': 3, 'Milestone 3': 4}, 986: {'Milestone 1': 3, 'Milestone 2': 5, 'Milestone 3': 5}, 842: {'Milestone 1': 3, 'Milestone 2': 4, 'Milestone 3': 4}, 1004: {'Milestone 1': 1, 'Milestone 2': 5, 'Milestone 3': 5}, 922: {'Milestone 1': 14, 'Milestone 2': 25, 'Milestone 3': 26}, 854: {'Milestone 1': 11, 'Milestone 2': 29, 'Milestone 3': 29}, 860: {'Milestone 1': 4, 'Milestone 2': 11, 'Milestone 3': 11}, 858: {'Milestone 1': 6, 'Milestone 2': 7, 'Milestone 3': 8}, 857: {'Milestone 1': 8, 'Milestone 2': 18, 'Milestone 3': 18}, 950: {'Milestone 1': 1, 'Milestone 2': 2, 'Milestone 3': 4}, 948: {'Milestone 1': 2, 'Milestone 2': 4, 'Milestone 3': 4}, 947: {'Milestone 1': 3, 'Milestone 2': 8, 'Milestone 3': 11}, 944: {'Milestone 1': 2, 'Milestone 2': 5, 'Milestone 3': 5}, 971: {'Milestone 1': 4, 'Milestone 2': 4}, 938: {'Milestone 1': 1, 'Milestone 3': 4}, 936: {'Milestone 1': 5, 'Milestone 2': 6, 'Milestone 3': 7}, 935: {'Milestone 1': 4, 'Milestone 2': 4, 'Milestone 3': 4}, 934: {'Milestone 1': 3, 'Milestone 3': 5}, 988: {'Milestone 1': 1, 'Milestone 3': 6}, 964: {'Milestone 1': 2, 'Milestone 2': 4, 'Milestone 3': 5}, 963: {'Milestone 1': 3, 'Milestone 2': 7, 'Milestone 3': 8}, 943: {'Milestone 1': 1, 'Milestone 2': 1, 'Milestone 3': 1}, 942: {'Milestone 1': 0, 'Milestone 2': 5, 'Milestone 3': 5}, 941: {'Milestone 1': 5, 'Milestone 2': 9, 'Milestone 3': 9}, 940: {'Milestone 1': 0, 'Milestone 2': 7, 'Milestone 3': 8}, 983: {'Milestone 1': 0, 'Milestone 2': 4, 'Milestone 3': 4}, 982: {'Milestone 1': 3, 'Milestone 2': 4, 'Milestone 3': 4}, 981: {'Milestone 1': 8, 'Milestone 2': 13, 'Milestone 3': 14}, 979: {'Milestone 1': 4, 'Milestone 2': 4, 'Milestone 3': 4}, 937: {'Milestone 2': 2, 'Milestone 3': 2}, 906: {'Milestone 2': 8, 'Milestone 3': 9}, 962: {'Milestone 2': 3, 'Milestone 3': 3}, 961: {'Milestone 2': 7, 'Milestone 3': 7}, 980: {'Milestone 2': 5, 'Milestone 3': 6}}

# %% [markdown]
# Convert data

# %%
bumpy_data = {k: v for k, v in bumpy_data.items() if any(vv != 0 for vv in v.values())}
df_bumpy = pd.DataFrame.from_dict(bumpy_data, orient='index')
df_bumpy = df_bumpy.sort_index()

fpc_data = {k: v for k, v in fpc_data.items() if any(vv != 0 for vv in v.values())}
df_fpc = pd.DataFrame.from_dict(fpc_data, orient='index')
df_fpc = df_fpc.sort_index()

lcom5_data = {k: v for k, v in lcom5_data.items() if any(vv != 0 for vv in v.values())}
df_lcom5 = pd.DataFrame.from_dict(lcom5_data, orient='index')
df_lcom5 = df_lcom5.sort_index()

lcom4_data = {k: v for k, v in lcom4_data.items() if any(vv != 0 for vv in v.values())}
df_lcom4 = pd.DataFrame.from_dict(lcom4_data, orient='index')
df_lcom4 = df_lcom4.sort_index()

# %% [markdown]
# # Plot data
# ## Bumpy road code metrics
# ### Bar chart

# %%
# Plot
plt.figure(figsize=(10, 5))
df_bumpy.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Bumpy Road (BR001) Count")
plt.title("Bumpy Road Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart

# %%
# Plot
plt.figure(figsize=(12, 6))
df_bumpy.plot(kind='line', alpha=0.6, marker='o', markersize=3, linewidth=1)

# Labels and Title
plt.xlabel("Milestone Files")
plt.ylabel("Bumpy Road (BR001) Count")
plt.title("BR001 Code Smell Evolution Across Milestones")
plt.xticks(rotation=45)
plt.legend([], title="Project ID", loc="upper left", fontsize="small")  # Hide legend for too many projects
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Normalize values to improve visualization
df_normalized = df_bumpy / df_bumpy.max().max()

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_normalized, cmap="coolwarm", linewidths=0.5, linecolor="gray")

# Labels
plt.xlabel("Projects")
plt.ylabel("Milestones")
plt.title("Bumpy Road Code Smell Intensity Over Time")

# Show plot
plt.show()

# %% [markdown]
# ### Line chart 2

# %%
plt.figure(figsize=(12, 6))

for student_id, scores in df_bumpy.iterrows():
    plt.plot(scores.index, scores.values, marker='o', linestyle='-', label=f"Project {student_id}")

plt.xlabel("Milestones")
plt.ylabel("Bumpy Score")
plt.title("Bumpy Score Progression Across Milestones")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Normalized bar chart

# %%
df_bumpy = df_bumpy / (df_bumpy.max() - df_bumpy.min())

# Plot
plt.figure(figsize=(10, 5))
df_bumpy.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Bumpy Road (BR001) Count")
plt.title("BR001 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ## Function parameter count
# ### Bar chart

# %%
# Plot
plt.figure(figsize=(10, 5))
df_fpc.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Too many parameters warning count")
plt.title("Too Many Parameters Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart

# %%
# Plot
plt.figure(figsize=(12, 6))
df_fpc.plot(kind='line', alpha=0.6, marker='o', markersize=3, linewidth=1)

# Labels and Title
plt.xlabel("Milestone Files")
plt.ylabel("Too many parameters warning count")
plt.title("Too Many Parameters Code Smell Evolution Across Milestones")
plt.xticks(rotation=45)
plt.legend([], title="Project ID", loc="upper left", fontsize="small")  # Hide legend for too many projects
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart 2

# %%
plt.figure(figsize=(12, 6))

for student_id, scores in df_fpc.iterrows():
    plt.plot(scores.index, scores.values, marker='o', linestyle='-', label=f"Project {student_id}")

plt.xlabel("Milestones")
plt.ylabel("Too many parameters warning count")
plt.title("Too Many Parameters Code Smell Progression Across Milestones")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Normalize values to improve visualization
df_normalized = df_bumpy / df_bumpy.max().max()

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_normalized, cmap="coolwarm", linewidths=0.5, linecolor="gray")

# Labels
plt.xlabel("Projects")
plt.ylabel("Milestones")
plt.title("Too Many Parameters Code Smell Intensity Over Time")

# Show plot
plt.show()

# %% [markdown]
# ### Normalized bar chart

# %%
df_fpc = df_fpc / (df_fpc.max() - df_fpc.min())

# Plot
plt.figure(figsize=(10, 5))
df_fpc.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Function parameter functions (FPC001) Count")
plt.title("FPC001 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ## LCOM5

# %% [markdown]
# ### Bar chart

# %%
# Plot
plt.figure(figsize=(10, 5))
df_lcom5.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Lack of Cohesion in Methods (LCOM5) Count")
plt.title("LCOM5 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart

# %%
# Plot
plt.figure(figsize=(12, 6))
df_lcom5.plot(kind='line', alpha=0.6, marker='o', markersize=3, linewidth=1)

# Labels and Title
plt.xlabel("Milestone Files")
plt.ylabel("Lack of Cohesion in Methods (LCOM5) Count")
plt.title("LCOM5 Code Smell Evolution Across Milestones")
plt.xticks(rotation=45)
plt.legend([], title="Project ID", loc="upper left", fontsize="small")  # Hide legend for too many projects
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart 2

# %%
plt.figure(figsize=(12, 6))

for student_id, scores in df_lcom5.iterrows():
    plt.plot(scores.index, scores.values, marker='o', linestyle='-', label=f"Project {student_id}")

plt.xlabel("Milestones")
plt.ylabel("LCOM5 Score")
plt.title("LCOM5 Score Progression Across Milestones")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Normalize values to improve visualization
df_normalized = df_lcom5 / df_lcom5.max().max()

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_normalized, cmap="coolwarm", linewidths=0.5, linecolor="gray")

# Labels
plt.xlabel("Projects")
plt.ylabel("Milestones")
plt.title("LCOM5 Code Smell Intensity Over Time")

# Show plot
plt.show()

# %% [markdown]
# ### Normalized bar chart

# %%
df_lcom5 = df_lcom5 / (df_lcom5.max() - df_lcom5.min())

# Plot
plt.figure(figsize=(10, 5))
df_lcom5.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Lack of Cohesion in Methods (LCOM5) Count")
plt.title("LCOM5 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ## LCOM4

# %% [markdown]
# ### Bar chart

# %%
# Plot
plt.figure(figsize=(10, 5))
df_lcom4.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Lack of Cohesion in Methods (LCOM4) Warning Count")
plt.title("LCOM4 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# ### Line chart

# %%
plt.figure(figsize=(12, 6))

for student_id, scores in df_lcom4.iterrows():
    plt.plot(scores.index, scores.values, marker='o', linestyle='-', label=f"Project {student_id}")

plt.xlabel("Milestones")
plt.ylabel("LCOM4 Score")
plt.title("LCOM4 Score Progression Across Milestones")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Normalize values to improve visualization
df_normalized = df_lcom4 / df_lcom4.max().max()

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_normalized, cmap="coolwarm", linewidths=0.5, linecolor="gray")

# Labels
plt.xlabel("Projects")
plt.ylabel("Milestones")
plt.title("LCOM4 Code Smell Intensity Over Time")

# Show plot
plt.show()

# %% [markdown]
# ### Normalized bar chart

# %%
df_lcom4 = df_lcom4 / (df_lcom4.max() - df_lcom4.min())

# Plot
plt.figure(figsize=(10, 5))
df_lcom4.plot(kind='bar', figsize=(10, 5))

# Labels and Title
plt.xlabel("Projects")
plt.ylabel("Lack of Cohesion in Methods (LCOM4) Count")
plt.title("LCOM4 Code Smell Evolution Across Milestones")
plt.legend(title="Milestones")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()
